# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# PRint the begingin of the logging
print("Begining Data Retrieval      ")
print("-----------------------------")

#Create counter
record_count = 1
set_count = 1
# Out:
# Begining Data Retrieval
# -----------------------------

# %%
#create random lats & lngs combinations
lats = np.random.uniform(-90.000, 90.000, size=1500)
lngs = np.random.uniform(-180.000, 180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# add the lats nad lngs to a list
coordinates = list(lats_lngs)

# %%
# Create a list for holding cities
cities = []
#identify the nearest city for each lats/lngs combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique add to the list
    if city not in cities:
        cities.append(city)

#print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | afgoye
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | saint-francois
# Processing Record 6 of Set 1 | dabakala
# Processing Record 7 of Set 1 | svetlaya
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 1 | ryotsu
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | puerto madero
# Processing Record 14 of Set 1 | motygino
# Processing Record 15 of Set 1 | rincon
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | grand-santi
# Processing Record 20 of Set 1 | sorong
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | urucui
# Processing Record 23 of Set 1 | taoudenni
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | alacranes
# Processing Record 27 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | sakakah
# Processing Record 30 of Set 1 | champerico
# Processing Record 31 of Set 1 | el guamo
# Processing Record 32 of Set 1 | marawi
# Processing Record 33 of Set 1 | esperance
# Processing Record 34 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | hambantota
# Processing Record 41 of Set 1 | el alto
# Processing Record 42 of Set 1 | iskateley
# Processing Record 43 of Set 1 | ambanja
# Processing Record 44 of Set 1 | starobaltachevo
# Processing Record 45 of Set 1 | lalomanu
# City not found. Skipping...
# Processing Record 46 of Set 1 | qesarya
# Processing Record 47 of Set 1 | iguape
# Processing Record 48 of Set 1 | araouane
# Processing Record 49 of Set 1 | kutum
# Processing Record 50 of Set 1 | benoy
# Processing Record 1 of Set 2 | aksu
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | mapiri
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | evensk
# Processing Record 8 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 2 | rania
# Processing Record 10 of Set 2 | isla vista
# Processing Record 11 of Set 2 | srednekolymsk
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | segou
# Processing Record 17 of Set 2 | ulaangom
# Processing Record 18 of Set 2 | polson
# Processing Record 19 of Set 2 | gizo
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | surazh
# Processing Record 24 of Set 2 | quatre cocos
# Processing Record 25 of Set 2 | leningradskiy
# Processing Record 26 of Set 2 | pangkalanbuun
# Processing Record 27 of Set 2 | dingle
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | dwarka
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | katsuura
# Processing Record 40 of Set 2 | faya
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | lages
# Processing Record 43 of Set 2 | savalou
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 2 | sumenep
# Processing Record 47 of Set 2 | katangli
# Processing Record 48 of Set 2 | berlevag
# Processing Record 49 of Set 2 | warren
# Processing Record 50 of Set 2 | hudson bay
# Processing Record 1 of Set 3 | sharlyk
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | emba
# Processing Record 4 of Set 3 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 5 of Set 3 | candawaga
# City not found. Skipping...
# Processing Record 6 of Set 3 | natal
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | bengkulu
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | voznesenye
# Processing Record 11 of Set 3 | chekhov
# Processing Record 12 of Set 3 | wad rawah
# Processing Record 13 of Set 3 | opotiki
# Processing Record 14 of Set 3 | cam ranh
# Processing Record 15 of Set 3 | nanakuli
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | haimen
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | mareeba
# Processing Record 20 of Set 3 | yanji
# Processing Record 21 of Set 3 | sampit
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 3 | tungor
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | chara
# Processing Record 27 of Set 3 | pitimbu
# Processing Record 28 of Set 3 | shitanjing
# Processing Record 29 of Set 3 | teeli
# Processing Record 30 of Set 3 | necochea
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | weatherford
# Processing Record 34 of Set 3 | tukrah
# Processing Record 35 of Set 3 | vestmanna
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | moron
# Processing Record 38 of Set 3 | atuona
# Processing Record 39 of Set 3 | paamiut
# Processing Record 40 of Set 3 | mecca
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | dharchula
# Processing Record 44 of Set 3 | neryungri
# Processing Record 45 of Set 3 | imamoglu
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | trois-rivieres
# Processing Record 48 of Set 3 | yurino
# Processing Record 49 of Set 3 | san cristobal
# Processing Record 50 of Set 3 | karratha
# Processing Record 1 of Set 4 | gamba
# Processing Record 2 of Set 4 | coahuayana
# Processing Record 3 of Set 4 | hilo
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | pisco
# Processing Record 6 of Set 4 | cherskiy
# Processing Record 7 of Set 4 | avera
# Processing Record 8 of Set 4 | bereda
# Processing Record 9 of Set 4 | poya
# Processing Record 10 of Set 4 | portobelo
# Processing Record 11 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 12 of Set 4 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 13 of Set 4 | afzalpur
# Processing Record 14 of Set 4 | dalen
# Processing Record 15 of Set 4 | mayumba
# Processing Record 16 of Set 4 | haines junction
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | filadelfia
# Processing Record 19 of Set 4 | vestmannaeyjar
# Processing Record 20 of Set 4 | gondar
# Processing Record 21 of Set 4 | vaini
# Processing Record 22 of Set 4 | hermanus
# Processing Record 23 of Set 4 | shimoda
# Processing Record 24 of Set 4 | mizdah
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | barrow
# Processing Record 27 of Set 4 | svetlogorsk
# Processing Record 28 of Set 4 | puerto narino
# Processing Record 29 of Set 4 | presidencia roque saenz pena
# Processing Record 30 of Set 4 | taksimo
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | turukhansk
# Processing Record 33 of Set 4 | qaqortoq
# Processing Record 34 of Set 4 | sechura
# Processing Record 35 of Set 4 | codrington
# Processing Record 36 of Set 4 | calama
# Processing Record 37 of Set 4 | guerrero negro
# Processing Record 38 of Set 4 | kenai
# Processing Record 39 of Set 4 | taga
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | corpus christi
# Processing Record 42 of Set 4 | stephenville
# Processing Record 43 of Set 4 | kandrian
# Processing Record 44 of Set 4 | chiredzi
# Processing Record 45 of Set 4 | faanui
# Processing Record 46 of Set 4 | padang
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | alofi
# Processing Record 49 of Set 4 | bredasdorp
# Processing Record 50 of Set 4 | tambul
# City not found. Skipping...
# Processing Record 1 of Set 5 | grindavik
# Processing Record 2 of Set 5 | liverpool
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | okhotsk
# Processing Record 5 of Set 5 | verkhnevilyuysk
# Processing Record 6 of Set 5 | hasaki
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | qandala
# Processing Record 9 of Set 5 | bloomington
# Processing Record 10 of Set 5 | touros
# Processing Record 11 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 5 | brokopondo
# Processing Record 13 of Set 5 | jalu
# Processing Record 14 of Set 5 | shelburne
# Processing Record 15 of Set 5 | sitka
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | kirkwall
# Processing Record 18 of Set 5 | kafue
# Processing Record 19 of Set 5 | toora-khem
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | belen
# Processing Record 22 of Set 5 | mutoko
# Processing Record 23 of Set 5 | oktyabrskoye
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 5 | waverly
# Processing Record 27 of Set 5 | los llanos de aridane
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | serenje
# Processing Record 30 of Set 5 | santa rosa
# Processing Record 31 of Set 5 | moranbah
# Processing Record 32 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 5 | beringovskiy
# Processing Record 35 of Set 5 | teguise
# Processing Record 36 of Set 5 | prince rupert
# Processing Record 37 of Set 5 | kamina
# Processing Record 38 of Set 5 | ribeira brava
# Processing Record 39 of Set 5 | klaksvik
# Processing Record 40 of Set 5 | rodrigues alves
# Processing Record 41 of Set 5 | tres arroyos
# Processing Record 42 of Set 5 | muroto
# Processing Record 43 of Set 5 | mogok
# Processing Record 44 of Set 5 | banjar
# Processing Record 45 of Set 5 | vardo
# Processing Record 46 of Set 5 | russell
# Processing Record 47 of Set 5 | bethel
# Processing Record 48 of Set 5 | thompson
# Processing Record 49 of Set 5 | kaeo
# Processing Record 50 of Set 5 | malakal
# Processing Record 1 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 6 | samarai
# Processing Record 3 of Set 6 | tineo
# Processing Record 4 of Set 6 | auki
# Processing Record 5 of Set 6 | nan
# Processing Record 6 of Set 6 | nome
# Processing Record 7 of Set 6 | kaitangata
# Processing Record 8 of Set 6 | kahului
# Processing Record 9 of Set 6 | safaga
# Processing Record 10 of Set 6 | vanimo
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | marsh harbour
# Processing Record 13 of Set 6 | talcahuano
# Processing Record 14 of Set 6 | goderich
# Processing Record 15 of Set 6 | kampong thum
# Processing Record 16 of Set 6 | kilindoni
# Processing Record 17 of Set 6 | vysokogornyy
# Processing Record 18 of Set 6 | caronport
# Processing Record 19 of Set 6 | tiksi
# Processing Record 20 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 21 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 6 | namibe
# Processing Record 23 of Set 6 | santa vitoria do palmar
# Processing Record 24 of Set 6 | bafoulabe
# Processing Record 25 of Set 6 | senador guiomard
# Processing Record 26 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 6 | hobyo
# Processing Record 28 of Set 6 | bonfim
# Processing Record 29 of Set 6 | tuktoyaktuk
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | verkhnyaya inta
# Processing Record 32 of Set 6 | moerai
# Processing Record 33 of Set 6 | vanderhoof
# Processing Record 34 of Set 6 | mahebourg
# Processing Record 35 of Set 6 | tabou
# Processing Record 36 of Set 6 | yulara
# Processing Record 37 of Set 6 | piranhas
# Processing Record 38 of Set 6 | aitape
# Processing Record 39 of Set 6 | tiarei
# Processing Record 40 of Set 6 | paso de los toros
# Processing Record 41 of Set 6 | coquimbo
# Processing Record 42 of Set 6 | jizan
# Processing Record 43 of Set 6 | sinnamary
# Processing Record 44 of Set 6 | foundiougne
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | pangody
# Processing Record 47 of Set 6 | finnsnes
# Processing Record 48 of Set 6 | vila do maio
# Processing Record 49 of Set 6 | syracuse
# Processing Record 50 of Set 6 | umm lajj
# Processing Record 1 of Set 7 | saint-augustin
# Processing Record 2 of Set 7 | kurilsk
# Processing Record 3 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 4 of Set 7 | novi troyany
# Processing Record 5 of Set 7 | sosnovskoye
# Processing Record 6 of Set 7 | half moon bay
# Processing Record 7 of Set 7 | issenye
# Processing Record 8 of Set 7 | dalvik
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | almaznyy
# Processing Record 11 of Set 7 | general roca
# Processing Record 12 of Set 7 | manono
# Processing Record 13 of Set 7 | olga
# Processing Record 14 of Set 7 | ketchikan
# Processing Record 15 of Set 7 | kalang
# Processing Record 16 of Set 7 | chuy
# Processing Record 17 of Set 7 | yangjiang
# Processing Record 18 of Set 7 | carnarvon
# Processing Record 19 of Set 7 | punta gorda
# Processing Record 20 of Set 7 | chipinge
# Processing Record 21 of Set 7 | lasa
# Processing Record 22 of Set 7 | huarmey
# Processing Record 23 of Set 7 | yuanping
# Processing Record 24 of Set 7 | termoli
# Processing Record 25 of Set 7 | changde
# Processing Record 26 of Set 7 | flinders
# Processing Record 27 of Set 7 | kiunga
# Processing Record 28 of Set 7 | esmeraldas
# Processing Record 29 of Set 7 | bousso
# Processing Record 30 of Set 7 | ito
# Processing Record 31 of Set 7 | ixtapa
# Processing Record 32 of Set 7 | brackenheim
# Processing Record 33 of Set 7 | acapulco
# Processing Record 34 of Set 7 | pelaya
# Processing Record 35 of Set 7 | praia da vitoria
# Processing Record 36 of Set 7 | port lincoln
# Processing Record 37 of Set 7 | karpathos
# Processing Record 38 of Set 7 | vyazemskiy
# Processing Record 39 of Set 7 | pangnirtung
# Processing Record 40 of Set 7 | margate
# Processing Record 41 of Set 7 | batemans bay
# Processing Record 42 of Set 7 | luderitz
# Processing Record 43 of Set 7 | castelo do piaui
# Processing Record 44 of Set 7 | grand gaube
# Processing Record 45 of Set 7 | vostok
# Processing Record 46 of Set 7 | umm kaddadah
# Processing Record 47 of Set 7 | sosva
# Processing Record 48 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 7 | chimbote
# Processing Record 50 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 8 | pasinler
# Processing Record 2 of Set 8 | bobbili
# Processing Record 3 of Set 8 | torrevieja
# Processing Record 4 of Set 8 | eirunepe
# Processing Record 5 of Set 8 | muncar
# Processing Record 6 of Set 8 | jishou
# Processing Record 7 of Set 8 | bairnsdale
# Processing Record 8 of Set 8 | burkburnett
# Processing Record 9 of Set 8 | ilulissat
# Processing Record 10 of Set 8 | sao felix do xingu
# Processing Record 11 of Set 8 | todos santos
# Processing Record 12 of Set 8 | lincoln
# Processing Record 13 of Set 8 | poum
# Processing Record 14 of Set 8 | adrar
# Processing Record 15 of Set 8 | isangel
# Processing Record 16 of Set 8 | bentiu
# Processing Record 17 of Set 8 | matagami
# Processing Record 18 of Set 8 | ancud
# Processing Record 19 of Set 8 | acari
# Processing Record 20 of Set 8 | puerto padre
# Processing Record 21 of Set 8 | komsomolskiy
# Processing Record 22 of Set 8 | inhambane
# Processing Record 23 of Set 8 | pacific grove
# Processing Record 24 of Set 8 | llangefni
# Processing Record 25 of Set 8 | hithadhoo
# Processing Record 26 of Set 8 | bonthe
# Processing Record 27 of Set 8 | wadi musa
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | wewak
# Processing Record 30 of Set 8 | conde
# Processing Record 31 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 8 | tucupita
# Processing Record 33 of Set 8 | inongo
# Processing Record 34 of Set 8 | sidi ali
# Processing Record 35 of Set 8 | wanning
# Processing Record 36 of Set 8 | maceio
# Processing Record 37 of Set 8 | tazovskiy
# Processing Record 38 of Set 8 | jutai
# Processing Record 39 of Set 8 | fossombrone
# Processing Record 40 of Set 8 | tura
# Processing Record 41 of Set 8 | jinchang
# Processing Record 42 of Set 8 | narsaq
# Processing Record 43 of Set 8 | santa cruz cabralia
# Processing Record 44 of Set 8 | jacareacanga
# Processing Record 45 of Set 8 | mount isa
# Processing Record 46 of Set 8 | byron bay
# Processing Record 47 of Set 8 | estelle
# Processing Record 48 of Set 8 | sistranda
# Processing Record 49 of Set 8 | hami
# Processing Record 50 of Set 8 | broken hill
# Processing Record 1 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 9 | penzance
# Processing Record 3 of Set 9 | salinopolis
# Processing Record 4 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 9 | aklavik
# Processing Record 6 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 9 | cidreira
# Processing Record 8 of Set 9 | egvekinot
# Processing Record 9 of Set 9 | luanda
# Processing Record 10 of Set 9 | sibolga
# Processing Record 11 of Set 9 | zaozerne
# Processing Record 12 of Set 9 | baruun-urt
# Processing Record 13 of Set 9 | wasilla
# Processing Record 14 of Set 9 | te anau
# Processing Record 15 of Set 9 | tiznit
# Processing Record 16 of Set 9 | pochutla
# Processing Record 17 of Set 9 | nikolskoye
# Processing Record 18 of Set 9 | nemuro
# Processing Record 19 of Set 9 | lavrentiya
# Processing Record 20 of Set 9 | honningsvag
# Processing Record 21 of Set 9 | fuerte olimpo
# Processing Record 22 of Set 9 | tucuman
# Processing Record 23 of Set 9 | comodoro rivadavia
# Processing Record 24 of Set 9 | talaya
# Processing Record 25 of Set 9 | seoul
# Processing Record 26 of Set 9 | troina
# Processing Record 27 of Set 9 | bud
# Processing Record 28 of Set 9 | kyren
# Processing Record 29 of Set 9 | valle nacional
# Processing Record 30 of Set 9 | pleasanton
# Processing Record 31 of Set 9 | labytnangi
# Processing Record 32 of Set 9 | aykhal
# Processing Record 33 of Set 9 | shizunai
# Processing Record 34 of Set 9 | helong
# Processing Record 35 of Set 9 | morondava
# Processing Record 36 of Set 9 | scarborough
# Processing Record 37 of Set 9 | sao joao da barra
# Processing Record 38 of Set 9 | dukat
# Processing Record 39 of Set 9 | baykit
# Processing Record 40 of Set 9 | port hedland
# Processing Record 41 of Set 9 | odweyne
# Processing Record 42 of Set 9 | kuala terengganu
# Processing Record 43 of Set 9 | stromness
# Processing Record 44 of Set 9 | carutapera
# Processing Record 45 of Set 9 | bilma
# Processing Record 46 of Set 9 | duz
# City not found. Skipping...
# Processing Record 47 of Set 9 | nelson bay
# Processing Record 48 of Set 9 | dongsheng
# Processing Record 49 of Set 9 | zhanaozen
# Processing Record 50 of Set 9 | bat yam
# Processing Record 1 of Set 10 | ayabe
# Processing Record 2 of Set 10 | laguna
# Processing Record 3 of Set 10 | quesnel
# Processing Record 4 of Set 10 | berdigestyakh
# Processing Record 5 of Set 10 | aksarka
# Processing Record 6 of Set 10 | mana
# Processing Record 7 of Set 10 | viedma
# Processing Record 8 of Set 10 | matay
# Processing Record 9 of Set 10 | cochrane
# Processing Record 10 of Set 10 | tyup
# Processing Record 11 of Set 10 | york
# Processing Record 12 of Set 10 | asfi
# Processing Record 13 of Set 10 | likasi
# Processing Record 14 of Set 10 | ugoofaaru
# Processing Record 15 of Set 10 | severodvinsk
# Processing Record 16 of Set 10 | turochak
# Processing Record 17 of Set 10 | mae hong son
# Processing Record 18 of Set 10 | ocampo
# Processing Record 19 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 20 of Set 10 | fort nelson
# Processing Record 21 of Set 10 | teguldet
# Processing Record 22 of Set 10 | noumea
# Processing Record 23 of Set 10 | navalcarnero
# Processing Record 24 of Set 10 | jiangyou
# Processing Record 25 of Set 10 | ambon
# Processing Record 26 of Set 10 | cabo san lucas
# Processing Record 27 of Set 10 | najran
# Processing Record 28 of Set 10 | palora
# Processing Record 29 of Set 10 | bilibino
# Processing Record 30 of Set 10 | yangshe
# Processing Record 31 of Set 10 | katobu
# Processing Record 32 of Set 10 | san quintin
# Processing Record 33 of Set 10 | husavik
# Processing Record 34 of Set 10 | plettenberg bay
# Processing Record 35 of Set 10 | belp
# Processing Record 36 of Set 10 | durban
# Processing Record 37 of Set 10 | havelock
# Processing Record 38 of Set 10 | jiayuguan
# Processing Record 39 of Set 10 | derzhavinsk
# Processing Record 40 of Set 10 | bardiyah
# Processing Record 41 of Set 10 | san-pedro
# Processing Record 42 of Set 10 | muros
# Processing Record 43 of Set 10 | tadine
# Processing Record 44 of Set 10 | maniitsoq
# Processing Record 45 of Set 10 | melilla
# Processing Record 46 of Set 10 | brigantine
# Processing Record 47 of Set 10 | fairbanks
# Processing Record 48 of Set 10 | great yarmouth
# Processing Record 49 of Set 10 | pindiga
# Processing Record 50 of Set 10 | barahona
# Processing Record 1 of Set 11 | sosua
# Processing Record 2 of Set 11 | keti bandar
# Processing Record 3 of Set 11 | lagoa
# Processing Record 4 of Set 11 | hartland
# Processing Record 5 of Set 11 | la mira
# Processing Record 6 of Set 11 | campbell river
# Processing Record 7 of Set 11 | sosnytsya
# Processing Record 8 of Set 11 | san policarpo
# Processing Record 9 of Set 11 | mount gambier
# Processing Record 10 of Set 11 | alice springs
# Processing Record 11 of Set 11 | vanavara
# Processing Record 12 of Set 11 | kitgum
# Processing Record 13 of Set 11 | calabozo
# Processing Record 14 of Set 11 | cabedelo
# Processing Record 15 of Set 11 | nouadhibou
# Processing Record 16 of Set 11 | abrego
# Processing Record 17 of Set 11 | mildura
# Processing Record 18 of Set 11 | pasighat
# Processing Record 19 of Set 11 | palana
# Processing Record 20 of Set 11 | labuhan
# Processing Record 21 of Set 11 | tigil
# Processing Record 22 of Set 11 | ariquemes
# Processing Record 23 of Set 11 | bac lieu
# Processing Record 24 of Set 11 | provideniya
# Processing Record 25 of Set 11 | savannah bight
# Processing Record 26 of Set 11 | hirara
# Processing Record 27 of Set 11 | sasebo
# Processing Record 28 of Set 11 | kefalos
# Processing Record 29 of Set 11 | kloulklubed
# Processing Record 30 of Set 11 | solnechnyy
# Processing Record 31 of Set 11 | clovis
# Processing Record 32 of Set 11 | drovyanaya
# Processing Record 33 of Set 11 | troitsko-pechorsk
# Processing Record 34 of Set 11 | kalanwali
# Processing Record 35 of Set 11 | sayyan
# Processing Record 36 of Set 11 | tobol
# Processing Record 37 of Set 11 | mufumbwe
# Processing Record 38 of Set 11 | catamarca
# Processing Record 39 of Set 11 | mayo
# Processing Record 40 of Set 11 | katunino
# Processing Record 41 of Set 11 | ust-nera
# Processing Record 42 of Set 11 | vaitape
# Processing Record 43 of Set 11 | murgab
# Processing Record 44 of Set 11 | atar
# Processing Record 45 of Set 11 | bathsheba
# Processing Record 46 of Set 11 | asau
# Processing Record 47 of Set 11 | souillac
# Processing Record 48 of Set 11 | saint-georges
# Processing Record 49 of Set 11 | andradina
# Processing Record 50 of Set 11 | anadyr
# Processing Record 1 of Set 12 | berezovka
# Processing Record 2 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 12 | rawson
# Processing Record 4 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 5 of Set 12 | yuncheng
# Processing Record 6 of Set 12 | dolores
# Processing Record 7 of Set 12 | shiyan
# Processing Record 8 of Set 12 | houma
# Processing Record 9 of Set 12 | salme
# Processing Record 10 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 11 of Set 12 | kieta
# Processing Record 12 of Set 12 | payakumbuh
# Processing Record 13 of Set 12 | boyolangu
# Processing Record 14 of Set 12 | nicolas bravo
# Processing Record 15 of Set 12 | tornio
# Processing Record 16 of Set 12 | lagos
# Processing Record 17 of Set 12 | cacheu
# Processing Record 18 of Set 12 | manuk mangkaw
# Processing Record 19 of Set 12 | cockburn town
# Processing Record 20 of Set 12 | sabang
# Processing Record 21 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 23 of Set 12 | tuy hoa
# Processing Record 24 of Set 12 | inuvik
# Processing Record 25 of Set 12 | benton harbor
# Processing Record 26 of Set 12 | henties bay
# Processing Record 27 of Set 12 | quetzaltepec
# City not found. Skipping...
# Processing Record 28 of Set 12 | fortuna
# Processing Record 29 of Set 12 | pobe
# Processing Record 30 of Set 12 | gore
# Processing Record 31 of Set 12 | redmond
# Processing Record 32 of Set 12 | zapolyarnyy
# Processing Record 33 of Set 12 | jos
# Processing Record 34 of Set 12 | djambala
# Processing Record 35 of Set 12 | mumford
# Processing Record 36 of Set 12 | bima
# Processing Record 37 of Set 12 | chlorakas
# Processing Record 38 of Set 12 | coxim
# Processing Record 39 of Set 12 | vredendal
# Processing Record 40 of Set 12 | atambua
# Processing Record 41 of Set 12 | luau
# Processing Record 42 of Set 12 | saint-louis
# Processing Record 43 of Set 12 | ho chi minh city
# Processing Record 44 of Set 12 | mantua
# Processing Record 45 of Set 12 | caorle
# Processing Record 46 of Set 12 | pagudpud
# Processing Record 47 of Set 12 | rielasingen-worblingen
# Processing Record 48 of Set 12 | cooma
# Processing Record 49 of Set 12 | imbituba
# Processing Record 50 of Set 12 | benghazi
# Processing Record 1 of Set 13 | huilong
# Processing Record 2 of Set 13 | broome
# Processing Record 3 of Set 13 | venado
# Processing Record 4 of Set 13 | avdon
# Processing Record 5 of Set 13 | samokov
# Processing Record 6 of Set 13 | rocha
# Processing Record 7 of Set 13 | chomun
# City not found. Skipping...
# Processing Record 8 of Set 13 | chalisgaon
# Processing Record 9 of Set 13 | chernyshevskiy
# Processing Record 10 of Set 13 | falakata
# Processing Record 11 of Set 13 | santander
# Processing Record 12 of Set 13 | atasu
# Processing Record 13 of Set 13 | arman
# Processing Record 14 of Set 13 | guatire
# Processing Record 15 of Set 13 | manaus
# Processing Record 16 of Set 13 | mazagao
# Processing Record 17 of Set 13 | saint anthony
# Processing Record 18 of Set 13 | maicao
# Processing Record 19 of Set 13 | marzuq
# Processing Record 20 of Set 13 | galle
# Processing Record 21 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 22 of Set 13 | polunochnoye
# Processing Record 23 of Set 13 | epinal
# Processing Record 24 of Set 13 | porto novo
# Processing Record 25 of Set 13 | takoradi
# Processing Record 26 of Set 13 | japura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 577

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     71.80        83          66
# 1       Busselton -33.6500  115.3333     56.05        63          85
# 2  Saint-Francois  46.4154    3.9054     61.18        83           0
# 3        Dabakala   8.3667   -4.4333     71.73        95          85
# 4        Svetlaya  46.5389  138.3297     65.66        90         100
# 5     Yellowknife  62.4560 -114.3525     64.92        68          20
# 6          Ryotsu  38.0833  138.4333     87.76        71           5
# 7    Kruisfontein -34.0033   24.7314     50.68        68           0
# 8          Hobart -42.8794  147.3294     61.27        54          75
# 9   Puerto Madero  14.7208  -92.4215     79.00       100          20
#
#    Wind Speed Country                 Date
# 0       10.67      PF  2021-07-31 05:23:57
# 1       15.77      AU  2021-07-31 05:23:58
# 2        3.44      FR  2021-07-31 05:23:58
# 3        4.27      CI  2021-07-31 05:23:58
# 4       12.66      RU  2021-07-31 05:23:59
# 5        6.91      CA  2021-07-31 05:23:59
# 6        6.11      JP  2021-07-31 05:24:00
# 7        5.10      ZA  2021-07-31 05:24:00
# 8        3.00      AU  2021-07-31 05:19:16
# 9        2.30      MX  2021-07-31 05:24:01

# %%
#reorder columns
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0           Rikitea      PF  2021-07-31 05:23:57 -23.1203 -134.9692     71.80
# 1         Busselton      AU  2021-07-31 05:23:58 -33.6500  115.3333     56.05
# 2    Saint-Francois      FR  2021-07-31 05:23:58  46.4154    3.9054     61.18
# 3          Dabakala      CI  2021-07-31 05:23:58   8.3667   -4.4333     71.73
# 4          Svetlaya      RU  2021-07-31 05:23:59  46.5389  138.3297     65.66
# ..              ...     ...                  ...      ...       ...       ...
# 572    Polunochnoye      RU  2021-07-31 05:27:48  60.8697   60.4153     64.02
# 573          Epinal      FR  2021-07-31 05:27:49  48.1833    6.4500     55.22
# 574      Porto Novo      BJ  2021-07-31 05:27:49   6.4965    2.6036     78.62
# 575        Takoradi      GH  2021-07-31 05:27:50   4.8845   -1.7554     74.79
# 576          Japura      ID  2021-07-31 05:27:50  -0.3167  102.3500     93.40
#
#      Humidity  Cloudiness  Wind Speed
# 0          83          66       10.67
# 1          63          85       15.77
# 2          83           0        3.44
# 3          95          85        4.27
# 4          90         100       12.66
# ..        ...         ...         ...
# 572        52          17        2.80
# 573        95          13        3.80
# 574        90          64        6.13
# 575        89          91        6.06
# 576        46          66        4.27
#
# [577 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("../weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. Humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("../weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("../weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("../weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                       Aldama
# Country                        MX
# Date          2021-07-30 01:10:16
# Lat                       22.9167
# Lng                      -98.0667
# Max Temp                     83.5
# Humidity                       76
# Cloudiness                    100
# Wind Speed                   7.29
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 558     True
# 559    False
# 560     True
# 561     True
# 562     True
# Name: Lat, Length: 563, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0          Lagoa      PT  2021-07-30 01:10:10  39.0500  -27.9833     69.82
# 3          Pevek      RU  2021-07-30 01:10:12  69.7008  170.3133     32.04
# 5      Raudeberg      NO  2021-07-30 01:10:12  61.9875    5.1352     60.19
# 7    Yellowknife      CA  2021-07-30 01:05:38  62.4560 -114.3525     71.29
# 10         Zemio      CF  2021-07-30 01:10:14   5.0314   25.1361     67.62
# ..           ...     ...                  ...      ...       ...       ...
# 557   Warrington      GB  2021-07-30 01:13:59  53.3925   -2.5802     58.26
# 558       Cosala      MX  2021-07-30 01:13:59  24.4125 -106.6908     81.10
# 560      Gogrial      SS  2021-07-30 01:14:00   8.5332   28.1004     72.28
# 561         Mana      GF  2021-07-30 01:14:01   5.6592  -53.7767     77.58
# 562        Avera      US  2021-07-30 01:14:01  33.1940  -82.5271     89.71
#
#      Humidity  Cloudiness  Wind Speed
# 0          90           0        9.04
# 3          98         100       25.64
# 5          93         100       15.30
# 7          46          88       11.01
# 10         94          67        1.50
# ..        ...         ...         ...
# 557        92         100        5.75
# 558        93          83        3.58
# 560        94         100        8.63
# 561        85           2        4.23
# 562        56           4        6.51
#
# [389 rows x 9 columns]

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for wind speed', 'wind speed',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for wind speed', 'wind speed',(-50,15))
