# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# PRint the begingin of the logging
print("Begining Data Retrieval      ")
print("-----------------------------")

#Create counter
record_count = 1
set_count = 1
# Out:
# Begining Data Retrieval
# -----------------------------

# %%
#create random lats & lngs combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# add the lats nad lngs to a list
coordinates = list(lats_lngs)

# %%
# Create a list for holding cities
cities = []
#identify the nearest city for each lats/lngs combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique add to the list
    if city not in cities:
        cities.append(city)

#print the city count to confirm sufficient count
len(cities)
# Out:
# 769

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date,
                          "Current Desc" : city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | kungurtug
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | sabana de torres
# Processing Record 6 of Set 1 | seymchan
# Processing Record 7 of Set 1 | labuhan
# Processing Record 8 of Set 1 | abu samrah
# Processing Record 9 of Set 1 | berezovyy
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | chuy
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | poronaysk
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | tual
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | flinders
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | ariogala
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | havelock
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | esperance
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | mumford
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | antalaha
# Processing Record 37 of Set 1 | lata
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | kautokeino
# Processing Record 40 of Set 1 | kortkeros
# Processing Record 41 of Set 1 | praia
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | codrington
# Processing Record 47 of Set 1 | lorengau
# Processing Record 48 of Set 1 | la cruz
# Processing Record 49 of Set 1 | stokmarknes
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | bytow
# Processing Record 2 of Set 2 | turukhansk
# Processing Record 3 of Set 2 | bubaque
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | mantua
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | coihaique
# Processing Record 9 of Set 2 | mujiayingzi
# Processing Record 10 of Set 2 | okha
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | grindavik
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | bairiki
# Processing Record 16 of Set 2 | preobrazheniye
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | newport
# Processing Record 21 of Set 2 | tiruvottiyur
# City not found. Skipping...
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | mandalgovi
# Processing Record 24 of Set 2 | sao joao da barra
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | chara
# Processing Record 28 of Set 2 | uglovka
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | brae
# Processing Record 31 of Set 2 | benoni
# Processing Record 32 of Set 2 | leshukonskoye
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | sao filipe
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | la ronge
# Processing Record 37 of Set 2 | sinnamary
# Processing Record 38 of Set 2 | dong hoi
# Processing Record 39 of Set 2 | alcobendas
# Processing Record 40 of Set 2 | lompoc
# Processing Record 41 of Set 2 | touros
# Processing Record 42 of Set 2 | asau
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | tezu
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 49 of Set 2 | basco
# Processing Record 50 of Set 2 | lillehammer
# Processing Record 1 of Set 3 | aykhal
# Processing Record 2 of Set 3 | namatanai
# Processing Record 3 of Set 3 | lavrentiya
# Processing Record 4 of Set 3 | atuona
# Processing Record 5 of Set 3 | santander
# Processing Record 6 of Set 3 | port moresby
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | palmer
# Processing Record 9 of Set 3 | gusau
# Processing Record 10 of Set 3 | bremervorde
# Processing Record 11 of Set 3 | vostok
# Processing Record 12 of Set 3 | dubbo
# Processing Record 13 of Set 3 | san patricio
# Processing Record 14 of Set 3 | lagoa
# Processing Record 15 of Set 3 | dickinson
# Processing Record 16 of Set 3 | yarkovo
# Processing Record 17 of Set 3 | kargopol
# Processing Record 18 of Set 3 | vila
# Processing Record 19 of Set 3 | goderich
# Processing Record 20 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 3 | moose factory
# Processing Record 22 of Set 3 | rocha
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | mudyuga
# City not found. Skipping...
# Processing Record 25 of Set 3 | meulaboh
# Processing Record 26 of Set 3 | evensk
# Processing Record 27 of Set 3 | ulaangom
# Processing Record 28 of Set 3 | saint-leu
# Processing Record 29 of Set 3 | chacabuco
# Processing Record 30 of Set 3 | hualmay
# Processing Record 31 of Set 3 | bereda
# Processing Record 32 of Set 3 | luganville
# Processing Record 33 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 3 | ixtapa
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | hasaki
# Processing Record 38 of Set 3 | uspenka
# Processing Record 39 of Set 3 | mar del plata
# Processing Record 40 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | kasempa
# Processing Record 43 of Set 3 | dingle
# Processing Record 44 of Set 3 | yar-sale
# Processing Record 45 of Set 3 | plover
# Processing Record 46 of Set 3 | goryachegorsk
# Processing Record 47 of Set 3 | san quintin
# Processing Record 48 of Set 3 | alcaniz
# Processing Record 49 of Set 3 | pergamino
# Processing Record 50 of Set 3 | adre
# Processing Record 1 of Set 4 | yamada
# Processing Record 2 of Set 4 | pacific grove
# Processing Record 3 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | starobaltachevo
# Processing Record 6 of Set 4 | brownsville
# Processing Record 7 of Set 4 | dunedin
# Processing Record 8 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 4 | novyy urengoy
# Processing Record 10 of Set 4 | nicolas bravo
# Processing Record 11 of Set 4 | trinidad
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | katsuura
# Processing Record 14 of Set 4 | muravlenko
# Processing Record 15 of Set 4 | inhambane
# Processing Record 16 of Set 4 | concepcion
# Processing Record 17 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 4 | demba
# Processing Record 19 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 4 | oranjemund
# Processing Record 21 of Set 4 | olafsvik
# Processing Record 22 of Set 4 | carnarvon
# Processing Record 23 of Set 4 | clyde river
# Processing Record 24 of Set 4 | port hardy
# Processing Record 25 of Set 4 | prainha
# Processing Record 26 of Set 4 | peace river
# Processing Record 27 of Set 4 | isangel
# Processing Record 28 of Set 4 | butaritari
# Processing Record 29 of Set 4 | kolokani
# Processing Record 30 of Set 4 | fortuna
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | belyy yar
# Processing Record 33 of Set 4 | changli
# Processing Record 34 of Set 4 | porto walter
# Processing Record 35 of Set 4 | umm lajj
# Processing Record 36 of Set 4 | inuvik
# Processing Record 37 of Set 4 | tautira
# Processing Record 38 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 4 | puerto narino
# Processing Record 40 of Set 4 | montlucon
# Processing Record 41 of Set 4 | santa isabel do rio negro
# Processing Record 42 of Set 4 | preetz
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | mineral wells
# Processing Record 45 of Set 4 | najran
# Processing Record 46 of Set 4 | kjollefjord
# Processing Record 47 of Set 4 | mnogovershinnyy
# Processing Record 48 of Set 4 | vuktyl
# Processing Record 49 of Set 4 | san luis
# Processing Record 50 of Set 4 | tala
# Processing Record 1 of Set 5 | puerto ayora
# Processing Record 2 of Set 5 | tasiilaq
# Processing Record 3 of Set 5 | robe
# Processing Record 4 of Set 5 | cam ranh
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | haines junction
# Processing Record 7 of Set 5 | mangaratiba
# Processing Record 8 of Set 5 | santa rosa
# Processing Record 9 of Set 5 | tocopilla
# Processing Record 10 of Set 5 | cape town
# Processing Record 11 of Set 5 | ambatofinandrahana
# Processing Record 12 of Set 5 | norman wells
# Processing Record 13 of Set 5 | zhangjiakou
# Processing Record 14 of Set 5 | east london
# Processing Record 15 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 5 | ilula
# Processing Record 18 of Set 5 | port blair
# Processing Record 19 of Set 5 | orchard homes
# Processing Record 20 of Set 5 | shimsk
# Processing Record 21 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | luanda
# Processing Record 24 of Set 5 | channel-port aux basques
# Processing Record 25 of Set 5 | hambantota
# Processing Record 26 of Set 5 | darhan
# Processing Record 27 of Set 5 | kaeo
# Processing Record 28 of Set 5 | westport
# Processing Record 29 of Set 5 | kaitangata
# Processing Record 30 of Set 5 | acapulco
# Processing Record 31 of Set 5 | karratha
# Processing Record 32 of Set 5 | sao gotardo
# Processing Record 33 of Set 5 | haysyn
# Processing Record 34 of Set 5 | deputatskiy
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | hobyo
# Processing Record 37 of Set 5 | reitz
# Processing Record 38 of Set 5 | ribas do rio pardo
# Processing Record 39 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 5 | namibe
# Processing Record 41 of Set 5 | uzumlu
# City not found. Skipping...
# Processing Record 42 of Set 5 | talara
# Processing Record 43 of Set 5 | green river
# Processing Record 44 of Set 5 | alice springs
# Processing Record 45 of Set 5 | cherskiy
# Processing Record 46 of Set 5 | havre
# Processing Record 47 of Set 5 | dikson
# Processing Record 48 of Set 5 | tokzar
# City not found. Skipping...
# Processing Record 49 of Set 5 | thompson
# Processing Record 50 of Set 5 | suba
# Processing Record 1 of Set 6 | ballina
# Processing Record 2 of Set 6 | ariquemes
# Processing Record 3 of Set 6 | constitucion
# Processing Record 4 of Set 6 | le port
# Processing Record 5 of Set 6 | te anau
# Processing Record 6 of Set 6 | seydi
# Processing Record 7 of Set 6 | saint george
# Processing Record 8 of Set 6 | yablochnyy
# Processing Record 9 of Set 6 | ahipara
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | salalah
# Processing Record 12 of Set 6 | northam
# Processing Record 13 of Set 6 | college
# Processing Record 14 of Set 6 | mareeba
# Processing Record 15 of Set 6 | rawson
# Processing Record 16 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 6 | hami
# Processing Record 18 of Set 6 | kayes
# Processing Record 19 of Set 6 | sao miguel do araguaia
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | sinazongwe
# Processing Record 22 of Set 6 | anajatuba
# Processing Record 23 of Set 6 | ishigaki
# Processing Record 24 of Set 6 | owando
# Processing Record 25 of Set 6 | cabedelo
# Processing Record 26 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 6 | konyshevka
# Processing Record 28 of Set 6 | santa cruz de la palma
# Processing Record 29 of Set 6 | aqtobe
# Processing Record 30 of Set 6 | midland
# Processing Record 31 of Set 6 | dwarahat
# Processing Record 32 of Set 6 | axim
# Processing Record 33 of Set 6 | havoysund
# Processing Record 34 of Set 6 | oriximina
# Processing Record 35 of Set 6 | richards bay
# Processing Record 36 of Set 6 | tatarsk
# Processing Record 37 of Set 6 | ola
# Processing Record 38 of Set 6 | batagay-alyta
# Processing Record 39 of Set 6 | tura
# Processing Record 40 of Set 6 | angoche
# Processing Record 41 of Set 6 | sur
# Processing Record 42 of Set 6 | dubuque
# Processing Record 43 of Set 6 | warrington
# Processing Record 44 of Set 6 | elbrus
# Processing Record 45 of Set 6 | alofi
# Processing Record 46 of Set 6 | bacungan
# Processing Record 47 of Set 6 | piste
# Processing Record 48 of Set 6 | flin flon
# Processing Record 49 of Set 6 | bengkulu
# Processing Record 50 of Set 6 | hirosaki
# Processing Record 1 of Set 7 | altay
# Processing Record 2 of Set 7 | wuda
# Processing Record 3 of Set 7 | palm coast
# Processing Record 4 of Set 7 | zhigansk
# Processing Record 5 of Set 7 | acopiara
# Processing Record 6 of Set 7 | aklavik
# Processing Record 7 of Set 7 | siilinjarvi
# Processing Record 8 of Set 7 | naifaru
# Processing Record 9 of Set 7 | bani
# Processing Record 10 of Set 7 | bam
# Processing Record 11 of Set 7 | lethem
# Processing Record 12 of Set 7 | wairoa
# Processing Record 13 of Set 7 | murchison
# Processing Record 14 of Set 7 | longyearbyen
# Processing Record 15 of Set 7 | lahij
# Processing Record 16 of Set 7 | chumikan
# Processing Record 17 of Set 7 | egvekinot
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | trat
# Processing Record 20 of Set 7 | srednekolymsk
# Processing Record 21 of Set 7 | calamar
# Processing Record 22 of Set 7 | turbat
# Processing Record 23 of Set 7 | misratah
# Processing Record 24 of Set 7 | florida
# Processing Record 25 of Set 7 | nome
# Processing Record 26 of Set 7 | veraval
# Processing Record 27 of Set 7 | tuy hoa
# Processing Record 28 of Set 7 | souillac
# Processing Record 29 of Set 7 | rio grande
# Processing Record 30 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 7 | guerrero negro
# Processing Record 32 of Set 7 | nuuk
# Processing Record 33 of Set 7 | yushan
# Processing Record 34 of Set 7 | kalabo
# Processing Record 35 of Set 7 | rolla
# Processing Record 36 of Set 7 | shaunavon
# Processing Record 37 of Set 7 | maningrida
# Processing Record 38 of Set 7 | chilliwack
# Processing Record 39 of Set 7 | broome
# Processing Record 40 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 7 | pisco
# Processing Record 42 of Set 7 | kavaratti
# Processing Record 43 of Set 7 | isetskoye
# Processing Record 44 of Set 7 | las vegas
# Processing Record 45 of Set 7 | skelleftea
# Processing Record 46 of Set 7 | sungurlu
# Processing Record 47 of Set 7 | duluth
# Processing Record 48 of Set 7 | ponta delgada
# Processing Record 49 of Set 7 | canto do buriti
# Processing Record 50 of Set 7 | liverpool
# Processing Record 1 of Set 8 | los llanos de aridane
# Processing Record 2 of Set 8 | faya
# Processing Record 3 of Set 8 | athabasca
# Processing Record 4 of Set 8 | rio gallegos
# Processing Record 5 of Set 8 | bathsheba
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | maraa
# Processing Record 8 of Set 8 | challans
# Processing Record 9 of Set 8 | broadstairs
# Processing Record 10 of Set 8 | ulaanbaatar
# Processing Record 11 of Set 8 | wajima
# Processing Record 12 of Set 8 | zhezkazgan
# Processing Record 13 of Set 8 | bilibino
# Processing Record 14 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 8 | capim grosso
# Processing Record 16 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 8 | gamba
# Processing Record 18 of Set 8 | jacareacanga
# Processing Record 19 of Set 8 | tuatapere
# Processing Record 20 of Set 8 | isla mujeres
# Processing Record 21 of Set 8 | vagur
# Processing Record 22 of Set 8 | vao
# Processing Record 23 of Set 8 | pizarro
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | bela vista
# Processing Record 26 of Set 8 | mayo
# Processing Record 27 of Set 8 | cidreira
# Processing Record 28 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 8 | djibo
# Processing Record 30 of Set 8 | hay river
# Processing Record 31 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 32 of Set 8 | lakatoro
# Processing Record 33 of Set 8 | nelson bay
# Processing Record 34 of Set 8 | cauquenes
# Processing Record 35 of Set 8 | bogande
# Processing Record 36 of Set 8 | baykit
# Processing Record 37 of Set 8 | mragowo
# Processing Record 38 of Set 8 | kuliyapitiya
# Processing Record 39 of Set 8 | champerico
# Processing Record 40 of Set 8 | avera
# Processing Record 41 of Set 8 | henties bay
# Processing Record 42 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 8 | myaundzha
# Processing Record 44 of Set 8 | lauf
# Processing Record 45 of Set 8 | merritt island
# Processing Record 46 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 47 of Set 8 | khorramabad
# Processing Record 48 of Set 8 | agnibilekrou
# Processing Record 49 of Set 8 | old saybrook
# Processing Record 50 of Set 8 | sohag
# Processing Record 1 of Set 9 | tibiri
# Processing Record 2 of Set 9 | villa carlos paz
# Processing Record 3 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 4 of Set 9 | kirya
# Processing Record 5 of Set 9 | kotma
# Processing Record 6 of Set 9 | saint-augustin
# Processing Record 7 of Set 9 | malmesbury
# Processing Record 8 of Set 9 | mandera
# Processing Record 9 of Set 9 | alta floresta
# Processing Record 10 of Set 9 | maridi
# Processing Record 11 of Set 9 | mugur-aksy
# Processing Record 12 of Set 9 | mocuba
# Processing Record 13 of Set 9 | kruisfontein
# Processing Record 14 of Set 9 | shimoda
# Processing Record 15 of Set 9 | babylon
# Processing Record 16 of Set 9 | sitka
# Processing Record 17 of Set 9 | kourou
# Processing Record 18 of Set 9 | waitati
# Processing Record 19 of Set 9 | timizart
# Processing Record 20 of Set 9 | helsinki
# Processing Record 21 of Set 9 | verkh-usugli
# Processing Record 22 of Set 9 | ostersund
# Processing Record 23 of Set 9 | nadym
# Processing Record 24 of Set 9 | takaka
# Processing Record 25 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 26 of Set 9 | portland
# Processing Record 27 of Set 9 | phrai bung
# City not found. Skipping...
# Processing Record 28 of Set 9 | la rioja
# Processing Record 29 of Set 9 | kashi
# Processing Record 30 of Set 9 | ambilobe
# Processing Record 31 of Set 9 | tadine
# Processing Record 32 of Set 9 | vestmannaeyjar
# Processing Record 33 of Set 9 | laguna
# Processing Record 34 of Set 9 | kununurra
# Processing Record 35 of Set 9 | bonthe
# Processing Record 36 of Set 9 | orangeburg
# Processing Record 37 of Set 9 | nosy varika
# Processing Record 38 of Set 9 | isaka
# Processing Record 39 of Set 9 | carbonia
# Processing Record 40 of Set 9 | saint anthony
# Processing Record 41 of Set 9 | karonga
# Processing Record 42 of Set 9 | camargo
# Processing Record 43 of Set 9 | marzuq
# Processing Record 44 of Set 9 | malanje
# Processing Record 45 of Set 9 | harper
# Processing Record 46 of Set 9 | araouane
# Processing Record 47 of Set 9 | beringovskiy
# Processing Record 48 of Set 9 | nanortalik
# Processing Record 49 of Set 9 | kandrian
# Processing Record 50 of Set 9 | coon rapids
# Processing Record 1 of Set 10 | padang
# Processing Record 2 of Set 10 | madimba
# Processing Record 3 of Set 10 | hinton
# Processing Record 4 of Set 10 | odienne
# Processing Record 5 of Set 10 | lebu
# Processing Record 6 of Set 10 | forestville
# Processing Record 7 of Set 10 | yankton
# Processing Record 8 of Set 10 | sorland
# Processing Record 9 of Set 10 | oktyabrskiy
# Processing Record 10 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 10 | maues
# Processing Record 12 of Set 10 | bambous virieux
# Processing Record 13 of Set 10 | praya
# Processing Record 14 of Set 10 | vera cruz
# Processing Record 15 of Set 10 | poum
# Processing Record 16 of Set 10 | la paz
# Processing Record 17 of Set 10 | camacupa
# Processing Record 18 of Set 10 | yuancheng
# Processing Record 19 of Set 10 | huarmey
# Processing Record 20 of Set 10 | eyl
# Processing Record 21 of Set 10 | nha trang
# Processing Record 22 of Set 10 | kirkuk
# Processing Record 23 of Set 10 | nueva loja
# Processing Record 24 of Set 10 | gornopravdinsk
# Processing Record 25 of Set 10 | andenes
# Processing Record 26 of Set 10 | tayu
# Processing Record 27 of Set 10 | acarau
# Processing Record 28 of Set 10 | hovd
# Processing Record 29 of Set 10 | navirai
# Processing Record 30 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 31 of Set 10 | szczytno
# Processing Record 32 of Set 10 | civitanova marche
# Processing Record 33 of Set 10 | pevek
# Processing Record 34 of Set 10 | port-cartier
# Processing Record 35 of Set 10 | gaya
# Processing Record 36 of Set 10 | makokou
# Processing Record 37 of Set 10 | changqing
# Processing Record 38 of Set 10 | dharmadam
# Processing Record 39 of Set 10 | cumberland
# Processing Record 40 of Set 10 | selfoss
# Processing Record 41 of Set 10 | angoram
# Processing Record 42 of Set 10 | taksimo
# Processing Record 43 of Set 10 | kishi
# Processing Record 44 of Set 10 | micheweni
# Processing Record 45 of Set 10 | nanganga
# Processing Record 46 of Set 10 | lodwar
# Processing Record 47 of Set 10 | fort nelson
# Processing Record 48 of Set 10 | matara
# Processing Record 49 of Set 10 | sao felix do xingu
# Processing Record 50 of Set 10 | sabang
# Processing Record 1 of Set 11 | mbaiki
# Processing Record 2 of Set 11 | pak phanang
# Processing Record 3 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 11 | peniche
# Processing Record 5 of Set 11 | ulladulla
# Processing Record 6 of Set 11 | boyolangu
# Processing Record 7 of Set 11 | nagato
# Processing Record 8 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 9 of Set 11 | birjand
# Processing Record 10 of Set 11 | vysokogornyy
# Processing Record 11 of Set 11 | dakar
# Processing Record 12 of Set 11 | muhos
# Processing Record 13 of Set 11 | narsaq
# Processing Record 14 of Set 11 | tazovskiy
# Processing Record 15 of Set 11 | vardo
# Processing Record 16 of Set 11 | buala
# Processing Record 17 of Set 11 | fort-shevchenko
# Processing Record 18 of Set 11 | necochea
# Processing Record 19 of Set 11 | naze
# Processing Record 20 of Set 11 | rundu
# Processing Record 21 of Set 11 | anchorage
# Processing Record 22 of Set 11 | igaracu do tiete
# Processing Record 23 of Set 11 | borama
# City not found. Skipping...
# Processing Record 24 of Set 11 | dekoa
# City not found. Skipping...
# Processing Record 25 of Set 11 | doha
# Processing Record 26 of Set 11 | simao
# Processing Record 27 of Set 11 | quang ngai
# Processing Record 28 of Set 11 | chanika
# Processing Record 29 of Set 11 | honningsvag
# Processing Record 30 of Set 11 | mount gambier
# Processing Record 31 of Set 11 | kloulklubed
# Processing Record 32 of Set 11 | taltal
# Processing Record 33 of Set 11 | samagaltay
# Processing Record 34 of Set 11 | ramachandrapuram
# Processing Record 35 of Set 11 | hervey bay
# Processing Record 36 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 11 | riga
# Processing Record 38 of Set 11 | monterey
# Processing Record 39 of Set 11 | akle
# Processing Record 40 of Set 11 | cayenne
# Processing Record 41 of Set 11 | octeville
# Processing Record 42 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 43 of Set 11 | nautla
# Processing Record 44 of Set 11 | teahupoo
# Processing Record 45 of Set 11 | inirida
# Processing Record 46 of Set 11 | kaspi
# Processing Record 47 of Set 11 | coquimbo
# Processing Record 48 of Set 11 | svetlyy
# Processing Record 49 of Set 11 | eregli
# Processing Record 50 of Set 11 | ndele
# Processing Record 1 of Set 12 | neiafu
# Processing Record 2 of Set 12 | pak chong
# Processing Record 3 of Set 12 | oussouye
# Processing Record 4 of Set 12 | yaan
# Processing Record 5 of Set 12 | anzio
# Processing Record 6 of Set 12 | mae sai
# Processing Record 7 of Set 12 | laredo
# Processing Record 8 of Set 12 | pereslavl-zalesskiy
# Processing Record 9 of Set 12 | nyimba
# Processing Record 10 of Set 12 | jieshi
# Processing Record 11 of Set 12 | thunder bay
# Processing Record 12 of Set 12 | ouesso
# Processing Record 13 of Set 12 | waddan
# Processing Record 14 of Set 12 | saint-jean-de-dieu
# City not found. Skipping...
# Processing Record 15 of Set 12 | karoi
# Processing Record 16 of Set 12 | half moon bay
# Processing Record 17 of Set 12 | chardara
# Processing Record 18 of Set 12 | srivardhan
# Processing Record 19 of Set 12 | ballymena
# Processing Record 20 of Set 12 | komsomolskiy
# Processing Record 21 of Set 12 | aksay
# Processing Record 22 of Set 12 | dhidhdhoo
# Processing Record 23 of Set 12 | krasnoselkup
# Processing Record 24 of Set 12 | comodoro rivadavia
# Processing Record 25 of Set 12 | pyaozerskiy
# Processing Record 26 of Set 12 | impfondo
# Processing Record 27 of Set 12 | north bend
# Processing Record 28 of Set 12 | puerto escondido
# Processing Record 29 of Set 12 | oyama
# Processing Record 30 of Set 12 | airai
# Processing Record 31 of Set 12 | dudinka
# Processing Record 32 of Set 12 | fuyang
# Processing Record 33 of Set 12 | korla
# Processing Record 34 of Set 12 | vredendal
# Processing Record 35 of Set 12 | elizabeth city
# Processing Record 36 of Set 12 | qaqortoq
# Processing Record 37 of Set 12 | deshna
# City not found. Skipping...
# Processing Record 38 of Set 12 | leninskoye
# Processing Record 39 of Set 12 | barra do garcas
# Processing Record 40 of Set 12 | tabou
# Processing Record 41 of Set 12 | ambon
# Processing Record 42 of Set 12 | tortoli
# Processing Record 43 of Set 12 | alghero
# Processing Record 44 of Set 12 | minggang
# Processing Record 45 of Set 12 | knyaze-volkonskoye
# Processing Record 46 of Set 12 | sabha
# Processing Record 47 of Set 12 | geraldton
# Processing Record 48 of Set 12 | sapele
# Processing Record 49 of Set 12 | lamu
# Processing Record 50 of Set 12 | cap malheureux
# Processing Record 1 of Set 13 | dothan
# Processing Record 2 of Set 13 | mauguio
# Processing Record 3 of Set 13 | abu zabad
# Processing Record 4 of Set 13 | severo-kurilsk
# Processing Record 5 of Set 13 | auki
# Processing Record 6 of Set 13 | zhanaozen
# Processing Record 7 of Set 13 | san fernando
# Processing Record 8 of Set 13 | ivdel
# Processing Record 9 of Set 13 | altamira
# Processing Record 10 of Set 13 | minot
# Processing Record 11 of Set 13 | barabinsk
# Processing Record 12 of Set 13 | skjervoy
# Processing Record 13 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 13 | yushu
# Processing Record 16 of Set 13 | krasnouralsk
# Processing Record 17 of Set 13 | vila franca do campo
# Processing Record 18 of Set 13 | kropotkin
# Processing Record 19 of Set 13 | burnie
# Processing Record 20 of Set 13 | pangnirtung
# Processing Record 21 of Set 13 | maldonado
# Processing Record 22 of Set 13 | shushtar
# Processing Record 23 of Set 13 | andreyevo
# Processing Record 24 of Set 13 | pareora
# Processing Record 25 of Set 13 | samarai
# Processing Record 26 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 13 | port macquarie
# Processing Record 28 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 29 of Set 13 | brasilia
# Processing Record 30 of Set 13 | jurado
# Processing Record 31 of Set 13 | klaksvik
# Processing Record 32 of Set 13 | kargasok
# Processing Record 33 of Set 13 | aden
# Processing Record 34 of Set 13 | sioux lookout
# Processing Record 35 of Set 13 | cockburn town
# Processing Record 36 of Set 13 | lander
# Processing Record 37 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 13 | soyo
# Processing Record 39 of Set 13 | the valley
# Processing Record 40 of Set 13 | aybak
# City not found. Skipping...
# Processing Record 41 of Set 13 | itarema
# Processing Record 42 of Set 13 | opuwo
# Processing Record 43 of Set 13 | copiapo
# Processing Record 44 of Set 13 | wenling
# Processing Record 45 of Set 13 | albert
# Processing Record 46 of Set 13 | tuburan
# Processing Record 47 of Set 13 | santa ana
# Processing Record 48 of Set 13 | jejuri
# Processing Record 49 of Set 13 | tomakomai
# Processing Record 50 of Set 13 | taitung
# Processing Record 1 of Set 14 | freeport
# Processing Record 2 of Set 14 | sobolevo
# Processing Record 3 of Set 14 | caravelas
# Processing Record 4 of Set 14 | stephenville
# Processing Record 5 of Set 14 | mino
# Processing Record 6 of Set 14 | broken hill
# Processing Record 7 of Set 14 | itanhaem
# Processing Record 8 of Set 14 | esparta
# Processing Record 9 of Set 14 | katha
# City not found. Skipping...
# Processing Record 10 of Set 14 | pochutla
# Processing Record 11 of Set 14 | quatre cocos
# Processing Record 12 of Set 14 | amapa
# Processing Record 13 of Set 14 | christchurch
# Processing Record 14 of Set 14 | cardston
# Processing Record 15 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 14 | tomatlan
# Processing Record 18 of Set 14 | georgiyevskoye
# Processing Record 19 of Set 14 | kahului
# Processing Record 20 of Set 14 | karsava
# Processing Record 21 of Set 14 | general roca
# Processing Record 22 of Set 14 | takoradi
# Processing Record 23 of Set 14 | polunochnoye
# Processing Record 24 of Set 14 | hamilton
# Processing Record 25 of Set 14 | catamarca
# Processing Record 26 of Set 14 | santa cruz del sur
# Processing Record 27 of Set 14 | kamyshin
# Processing Record 28 of Set 14 | cruzeiro do sul
# Processing Record 29 of Set 14 | saint-joseph
# Processing Record 30 of Set 14 | adrar
# Processing Record 31 of Set 14 | evreux
# Processing Record 32 of Set 14 | tessalit
# Processing Record 33 of Set 14 | esqueda
# Processing Record 34 of Set 14 | guiglo
# Processing Record 35 of Set 14 | stanghelle
# Processing Record 36 of Set 14 | itoman
# Processing Record 37 of Set 14 | usinsk
# Processing Record 38 of Set 14 | anloga
# Processing Record 39 of Set 14 | makakilo city
# Processing Record 40 of Set 14 | uchiza
# Processing Record 41 of Set 14 | amga
# Processing Record 42 of Set 14 | ambanja
# Processing Record 43 of Set 14 | walvis bay
# Processing Record 44 of Set 14 | kazan
# Processing Record 45 of Set 14 | rabat
# Processing Record 46 of Set 14 | mengyin
# Processing Record 47 of Set 14 | camacha
# Processing Record 48 of Set 14 | praia da vitoria
# Processing Record 49 of Set 14 | koszalin
# Processing Record 50 of Set 14 | jalu
# Processing Record 1 of Set 15 | tacna
# Processing Record 2 of Set 15 | maun
# Processing Record 3 of Set 15 | nishihara
# Processing Record 4 of Set 15 | riom
# Processing Record 5 of Set 15 | nassau
# Processing Record 6 of Set 15 | cururupu
# Processing Record 7 of Set 15 | bambanglipuro
# Processing Record 8 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 9 of Set 15 | slave lake
# Processing Record 10 of Set 15 | mandan
# Processing Record 11 of Set 15 | zhuhai
# Processing Record 12 of Set 15 | pitimbu
# Processing Record 13 of Set 15 | ketchikan
# Processing Record 14 of Set 15 | iralaya
# Processing Record 15 of Set 15 | catuday
# Processing Record 16 of Set 15 | murmino
# Processing Record 17 of Set 15 | orai
# Processing Record 18 of Set 15 | kuytun
# Processing Record 19 of Set 15 | canyon
# Processing Record 20 of Set 15 | port-gentil
# Processing Record 21 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 15 | batsfjord
# Processing Record 24 of Set 15 | port hedland
# Processing Record 25 of Set 15 | bonavista
# Processing Record 26 of Set 15 | port lincoln
# Processing Record 27 of Set 15 | olavarria
# Processing Record 28 of Set 15 | russell
# Processing Record 29 of Set 15 | ivanava
# Processing Record 30 of Set 15 | husavik
# Processing Record 31 of Set 15 | galesong
# Processing Record 32 of Set 15 | poya
# Processing Record 33 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 15 | tramagal
# Processing Record 35 of Set 15 | aviles
# Processing Record 36 of Set 15 | taoudenni
# Processing Record 37 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 15 | yumen
# Processing Record 39 of Set 15 | san roque
# Processing Record 40 of Set 15 | cananeia
# Processing Record 41 of Set 15 | lake charles
# Processing Record 42 of Set 15 | leh
# Processing Record 43 of Set 15 | milkovo
# Processing Record 44 of Set 15 | sao manuel
# Processing Record 45 of Set 15 | nouadhibou
# Processing Record 46 of Set 15 | alexandria
# Processing Record 47 of Set 15 | sisimiut
# Processing Record 48 of Set 15 | elat
# Processing Record 49 of Set 15 | dordrecht
# Processing Record 50 of Set 15 | ust-omchug
# Processing Record 1 of Set 16 | novorzhev
# Processing Record 2 of Set 16 | brive-la-gaillarde
# Processing Record 3 of Set 16 | bay roberts
# Processing Record 4 of Set 16 | ojos de agua
# Processing Record 5 of Set 16 | saint-francois
# Processing Record 6 of Set 16 | emerald
# Processing Record 7 of Set 16 | seoul
# Processing Record 8 of Set 16 | techiman
# Processing Record 9 of Set 16 | ust-tsilma
# Processing Record 10 of Set 16 | sorong
# Processing Record 11 of Set 16 | shingu
# Processing Record 12 of Set 16 | zharkent
# Processing Record 13 of Set 16 | camana
# Processing Record 14 of Set 16 | shelburne
# Processing Record 15 of Set 16 | mogadishu
# Processing Record 16 of Set 16 | yudong
# Processing Record 17 of Set 16 | san vicente
# Processing Record 18 of Set 16 | liwale
# Processing Record 19 of Set 16 | tianmen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hermanus -34.4187   19.2345     51.91        79           4
# 1        Georgetown   5.4112  100.3354     87.75        66          20
# 2         Kungurtug  50.5994   97.5228     72.37        29         100
# 3            Albany  42.6001  -73.9662     58.87        79           0
# 4  Sabana De Torres   7.3915  -73.4957     79.41        91          35
# 5          Seymchan  62.8833  152.4333     60.01        39          20
# 6           Labuhan  -6.8844  112.2051     86.13        59           0
# 7        Abu Samrah  35.3029   37.1841     76.93        56           0
# 8         Berezovyy  51.6667  135.7000     55.24        83         100
# 9       Port Alfred -33.5906   26.8910     57.58        64           0
#
#    Wind Speed Country      Current Desc
# 0        5.46      ZA         clear sky
# 1        5.75      MY        few clouds
# 2        2.21      RU   overcast clouds
# 3        5.57      US         clear sky
# 4        3.80      CO  scattered clouds
# 5        2.19      RU        few clouds
# 6        7.45      ID         clear sky
# 7        7.54      SY         clear sky
# 8        5.35      RU   overcast clouds
# 9        6.46      ZA         clear sky

# %%
#reorder columns
new_column_order = ['City', 'Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Current Desc']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hermanus      ZA -34.4187   19.2345     51.91        79
# 1          Georgetown      MY   5.4112  100.3354     87.75        66
# 2           Kungurtug      RU  50.5994   97.5228     72.37        29
# 3              Albany      US  42.6001  -73.9662     58.87        79
# 4    Sabana De Torres      CO   7.3915  -73.4957     79.41        91
# ..                ...     ...      ...       ...       ...       ...
# 701         Mogadishu      SO   2.0371   45.3438     76.39        76
# 702            Yudong      CN  29.3850  106.5194     96.49        58
# 703       San Vicente      AR -26.6167  -54.1333     39.51        78
# 704            Liwale      TZ  -9.7667   37.9333     62.83        84
# 705           Tianmen      CN  30.6516  113.1603     91.42        65
#
#      Cloudiness  Wind Speed      Current Desc
# 0             4        5.46         clear sky
# 1            20        5.75        few clouds
# 2           100        2.21   overcast clouds
# 3             0        5.57         clear sky
# 4            35        3.80  scattered clouds
# ..          ...         ...               ...
# 701          57       18.05     broken clouds
# 702          99        2.06        light rain
# 703          49        2.68  scattered clouds
# 704           6        5.75         clear sky
# 705           0        4.74         clear sky
#
# [706 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
